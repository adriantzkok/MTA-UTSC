# %% [markdown]
# # Results pull

# %%
import pandas as pd

import unicodedata

# %%
df_points = pd.read_csv("RawData/Points.csv")

# %%
df_points.head(2)
# Out:
#    Pos.      Team  G  Pld  W  D  L  Pts  GF  GA GD
# 0     1    France  C    7  6  1  0   19  14   6  8
# 1     2   Croatia  D    7  4  2  1   14  14   9  5

# %%
df_points['Team'][1]
# Out:
# '\xa0Croatia'

# %%
df_points['Team'] = df_points['Team'].apply(lambda x: x.replace('\xa0', '').strip())

# %%
df_points['Team'][1]
# Out:
# 'Croatia'

# %%
df_points.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pos.    32 non-null     int64
#  1   Team    32 non-null     object
#  2   G       32 non-null     object
#  3   Pld     32 non-null     int64
#  4   W       32 non-null     int64
#  5   D       32 non-null     int64
#  6   L       32 non-null     int64
#  7   Pts     32 non-null     int64
#  8   GF      32 non-null     int64
#  9   GA      32 non-null     int64
#  10  GD      32 non-null     object
# dtypes: int64(8), object(3)
# memory usage: 2.9+ KB

# %%
df_points.columns
# Out:
# Index(['Pos.', 'Team', 'G', 'Pld', 'W', 'D', 'L', 'Pts', 'GF', 'GA', 'GD'], dtype='object')

# %%
df_results = pd.read_csv("RawData/Results.csv")

# %%
df_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  32 non-null     object
#  1   Score    32 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 640.0+ bytes

# %%
df_results.head(3)
# Out:
#         Country  Score
# 0       Uruguay      3
# 1        Russia      3
# 2  Saudi Arabia      1

# %%
df_results.columns
# Out:
# Index(['Country', 'Score'], dtype='object')

# %%
df_physical =  pd.merge(df_results, df_points, left_on = 'Country', right_on = 'Team')

# %%
df_physical
# Out:
#          Country  Score  Pos.          Team  G  Pld  W  D  L  Pts  GF  GA  GD
# 0        Uruguay      3     5       Uruguay  A    5  4  0  1   12   7   3   4
# 1         Russia      3     8        Russia  A    5  2  2  1    8  11   7   4
# 2   Saudi Arabia      1    26  Saudi Arabia  A    3  1  0  2    3   2   7  −5
# 3          Egypt      1    31         Egypt  A    3  0  0  3    0   2   6  −4
# 4          Spain      2    10         Spain  B    4  1  3  0    6   7   6   1
# 5       Portugal      2    13      Portugal  B    4  1  2  1    5   6   6   0
# 6           Iran      1    18          Iran  B    3  1  1  1    4   2   2   0
# 7        Morocco      1    27       Morocco  B    3  0  1  2    1   2   4  −2
# 8         France      7     1        France  C    7  6  1  0   19  14   6   8
# 9        Denmark      2    11       Denmark  C    4  1  3  0    6   3   2   1
# 10          Peru      1    20          Peru  C    3  1  0  2    3   2   2   0
# ...

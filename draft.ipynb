# %% [markdown]
# # FIFA CASE

# %% [markdown]
# “Defenders often need to be physically strong in order to compete and progress in
# the world cup”.

# %% [markdown]
# ## Imports Python Packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from fuzzywuzzy import fuzz
# Out:
# /Users/guozixian/opt/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# ## Player Data for the 2018 world cup
#
# First, we import all the players that played during the last world cup (2018).

# %%
df_fifa = pd.read_csv("fifadata.csv")

# %%
df_fifa.Position.unique()
# Out:
# array(['GK', 'DF', 'MF', 'FW'], dtype=object)

# %%
# to Only Select defenders
df_fifa = df_fifa[df_fifa['Position'] == "DF"]
df_fifa['Date Of Birth'] = pd.to_datetime(df_fifa['Date Of Birth'])

# %%
df_fifa
# Out:
#         Team Group  Squad Number Position             Player Date Of Birth  \
# 1      Egypt     A             2       DF           Ali Gabr    1989-01-01
# 2      Egypt     A             3       DF   Ahmed Elmohamady    1987-09-09
# 5      Egypt     A             6       DF       Ahmed Hegazi    1991-01-25
# 6      Egypt     A             7       DF        Ahmed Fathy    1984-11-10
# 11     Egypt     A            12       DF       Ayman Ashraf    1991-04-09
# ..       ...   ...           ...      ...                ...           ...
# 715  Senegal     H             3       DF  Kalidou Koulibaly    1991-06-20
# 716  Senegal     H             4       DF        Kara Mbodji    1989-11-22
# 724  Senegal     H            12       DF    Youssouf Sabaly    1993-03-05
# 733  Senegal     H            21       DF     Lamine Gassama    1989-10-20
# 734  Senegal     H            22       DF       Moussa Wagué    1998-10-04
#
#      Age  Caps  Goals                  Club  Player Count
# 1     29    20      1  West Bromwich Albion             1
# 2     30    77      2           Aston Villa             1
# 5     27    44      1  West Bromwich Albion             1
# 6     33   125      3               Al Ahly             1
# 11    27     4      0               Al Ahly             1
# ..   ...   ...    ...                   ...           ...
# 715   26    24      0                Napoli             1
# 716   28    51      5            Anderlecht             1
# 724   25     3      0              Bordeaux             1
# 733   28    35      0            Alanyaspor             1
# 734   19     9      0                 Eupen             1
#
# [248 rows x 11 columns]

# %%
df_fifa.Club.unique()
# Out:
# array(['West Bromwich Albion', 'Aston Villa', 'Al Ahly', 'Al-Fateh',
#        'Zamalek', 'CSKA Moscow', 'Spartak Moscow', 'Akhmat Grozny',
#        'Rubin Kazan', 'Zenit Saint Petersburg', 'Al-Ahli', 'Al-Hilal',
#        'Al-Nassr', 'Atlético Madrid', 'Peñarol', 'Independiente', 'Porto',
#        'Sporting CP', 'Lazio', 'Olympiacos', 'Esteghlal', 'Al-Sadd',
#        'Padideh', 'Oostende', 'Real Madrid', 'Lille',
#        'İstanbul Başakşehir', 'Juventus', 'Wolverhampton Wanderers',
#        'Fenerbahçe', 'Rangers', 'Beşiktaş', 'Borussia Dortmund',
#        'Dalian Yifang', 'Benfica', 'Napoli', 'Southampton', 'Barcelona',
#        'Real Sociedad', 'Chelsea', 'Arsenal', 'Yokohama F. Marinos',
#        'Millwall', 'Suwon Samsung Bluewings', 'Bursaspor',
#        'Western Sydney Wanderers', 'Grasshoppers',
#        'Borussia Mönchengladbach', 'Sevilla', 'Ipswich Town',
#        'Huddersfield Town', 'Brentford', 'Udinese', 'VfB Stuttgart',
#        'Paris Saint-Germain', 'Marseille', 'Monaco', 'Manchester City',
#        'Atlético Junior', 'Universitario', 'Puebla', 'Alianza Lima',
#        'Flamengo', 'Veracruz', 'Lobos BUAP', 'Melgar', 'Ajax', 'Torino',
#        'Roma', 'Hebei China Fortune', 'Manchester United', 'Sampdoria',
#        'Lokomotiv Moscow', 'Liverpool', 'Bayer Leverkusen',
#        'Red Bull Salzburg', 'Dynamo Kyiv', 'Valur', 'Rostov', 'Aberdeen',
#        'Levski Sofia', 'Bristol City', 'Lokeren', 'Amkar Perm',
#        'Cercle Brugge', 'Mainz 05', 'Nantes', 'ADO Den Haag', 'Kasımpaşa',
#        'Inter Milan', 'Grêmio', 'Corinthians', 'Águilas Doradas',
#        'Bologna', 'Norrköping', 'Espanyol', 'Sunderland',
#        'Minnesota United', 'Celtic', 'Vancouver Whitecaps FC',
#        'New York City FC', 'Villarreal', 'Anderlecht', 'Werder Bremen',
#        'Red Star Belgrade', 'Fiorentina', 'Toulouse', 'Basel', 'Milan',
#        'Antalyaspor', 'Deportivo La Coruña', 'Hertha BSC', '1. FC Köln',
#        'Bayern Munich', 'UANL', 'Eintracht Frankfurt', 'Atlas', 'América',
#        'Jeonbuk Hyundai Motors', 'Sagan Tosu', 'Jeju United',
#        'Seongnam FC', 'Ulsan Hyundai', 'Sangju Sangmu',
#        'Guangzhou Evergrande', 'FC Tokyo', 'FC Seoul', 'Krasnodar',
#        'Swansea City', 'Leeds United', 'Tottenham Hotspur',
#        'Leicester City', 'New York Red Bulls', 'San Jose Earthquakes',
#        'Seattle Sounders FC', 'Houston Dynamo', 'Dunajská Streda',
#        'Olimpia', 'Municipal', 'CS Sfaxien', 'Dijon', 'Étoile du Sahel',
#        'Gent', 'Pachuca', 'PSV Eindhoven', 'Girona', 'Boca Juniors',
#        'Kashima Antlers', 'Galatasaray', 'Urawa Red Diamonds',
#        'Hamburger SV', 'Legia Warsaw', 'SPAL', 'Valenciennes', 'Bordeaux',
#        'Alanyaspor', 'Eupen'], dtype=object)

# %%
df_fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 248 entries, 1 to 734
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Team           248 non-null    object
#  1   Group          248 non-null    object
#  2   Squad Number   248 non-null    int64
#  3   Position       248 non-null    object
#  4   Player         248 non-null    object
#  5   Date Of Birth  248 non-null    datetime64[ns]
#  6   Age            248 non-null    int64
#  7   Caps           248 non-null    int64
#  8   Goals          248 non-null    int64
#  9   Club           248 non-null    object
#  10  Player Count   248 non-null    int64
# dtypes: datetime64[ns](1), int64(5), object(5)
# memory usage: 23.2+ KB

# %%
df_fifa.Team.unique()
# Out:
# array(['Egypt', 'Russia', 'Saudi Arabia', 'Uruguay', 'Iran', 'Morocco',
#        'Portugal', 'Spain', 'Australia', 'Denmark', 'France', 'Peru',
#        'Argentina', 'Croatia', 'Iceland', 'Nigeria', 'Brazil',
#        'Costa Rica', 'Serbia', 'Switzerland', 'Germany', 'Mexico',
#        'South Korea', 'Sweden', 'Belgium', 'England', 'Panama', 'Tunisia',
#        'Colombia', 'Japan', 'Poland', 'Senegal'], dtype=object)

# %%
df_fifa.nunique()
# Out:
# Team              32
# Group              8
# Squad Number      20
# Position           1
# Player           248
# Date Of Birth    237
# Age               21
# Caps              89
# Goals             14
# Club             157
# Player Count       1
# dtype: int64

# %% [markdown]
# ## Importing Player Data
#
# We then import individual player data in general.

# %%
df_players = pd.read_csv("players_18.csv")
df_players['dob'] = pd.to_datetime(df_players['dob'])

# %%
df_players
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4         176580  https://sofifa.com/player/176580/luis-suarez/1...
# ...          ...                                                ...
# 17949     237463  https://sofifa.com/player/237463/adam-kelsey/1...
# 17950     231381  https://sofifa.com/player/231381/jordan-young/...
# 17951     240404  https://sofifa.com/player/240404/jack-keeble/1...
# 17952      11728  https://sofifa.com/player/11728/barry-richards...
# 17953     235352  https://sofifa.com/player/235352/tommy-kassemo...
#
#               short_name                            long_name  age        dob  \
# 0      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   32 1985-02-05
# 1               L. Messi       Lionel Andrés Messi Cuccittini   30 1987-06-24
# 2                 Neymar        Neymar da Silva Santos Júnior   25 1992-02-05
# 3               M. Neuer                         Manuel Neuer   31 1986-03-27
# 4              L. Suárez             Luis Alberto Suárez Díaz   30 1987-01-24
# ...                  ...                                  ...  ...        ...
# 17949          A. Kelsey                          Adam Kelsey   17 1999-11-12
# 17950           J. Young                         Jordan Young   17 1999-07-31
# 17951          J. Keeble                          Jack Keeble   18 1999-03-22
# 17952      B. Richardson                     Barry Richardson   47 1969-08-05
# 17953       T. Käßemodel                      Tommy Käßemodel   28 1988-08-09
#
#        height_cm  weight_kg nationality            club_name  ...   lwb   ldm  \
# 0            185         80    Portugal          Real Madrid  ...  66+4  62+4
# 1            170         72   Argentina         FC Barcelona  ...  62+4  59+4
# 2            175         68      Brazil  Paris Saint-Germain  ...  64+4  59+4
# 3            193         92     Germany    FC Bayern München  ...  36+4  41+4
# 4            182         86     Uruguay         FC Barcelona  ...  68+4  65+4
# ...          ...        ...         ...                  ...  ...   ...   ...
# 17949        188         74     England    Scunthorpe United  ...  18+1  18+1
# 17950        175         71    Scotland         Swindon Town  ...  32+1  29+1
# 17951        172         66     England         Grimsby Town  ...  44+1  41+1
# 17952        185         77     England    Wycombe Wanderers  ...  20+1  21+1
# 17953        173         75     Germany    FC Erzgebirge Aue  ...  38+1  42+1
#
#         cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0      62+4  62+4  66+4  61+4  53+4  53+4  53+4  61+4
# 1      59+4  59+4  62+4  57+4  45+4  45+4  45+4  57+4
# 2      59+4  59+4  64+4  59+4  46+4  46+4  46+4  59+4
# 3      41+4  41+4  36+4  34+4  33+4  33+4  33+4  34+4
# 4      65+4  65+4  68+4  64+4  58+4  58+4  58+4  64+4
# ...     ...   ...   ...   ...   ...   ...   ...   ...
# 17949  18+1  18+1  18+1  17+1  17+1  17+1  17+1  17+1
# 17950  29+1  29+1  32+1  31+1  28+1  28+1  28+1  31+1
# 17951  41+1  41+1  44+1  46+1  45+1  45+1  45+1  46+1
# 17952  21+1  21+1  20+1  20+1  22+1  22+1  22+1  20+1
# 17953  42+1  42+1  38+1  37+1  38+1  38+1  38+1  37+1
#
# [17954 rows x 106 columns]

# %% [markdown]
# We want to select only the columns which would represent physical strength to answer the prompt.

# %%
df_players.columns.tolist()
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club_name',
#  'league_name',
#  'league_rank',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking',
#  'defending_standing_tackle',
#  'defending_sliding_tackle',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb']

# %% [markdown]
# Thus, the only physical attributes here that we can use are height, and weight

# %% [markdown]
# ## Merging the Datasets toghether

# %%
df_tgt = pd.merge(df_fifa, df_players, left_on = ['Date Of Birth', 'Team'] ,right_on = ['dob', 'nationality'])

# %%
df_names = df_tgt[['long_name', 'Player']]

# %%
df_names["ratio"] = 0
# Out:
# /var/folders/bb/7x1l6zmd3blblnxk0dz1d27h0000gn/T/ipykernel_55533/3399366239.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_names["ratio"] = 0

# %%
def matchscore(score1, score2):
    return fuzz.ratio(score1, score2)

# %%
for i in range(len(df_names)):
    value_1 = df_names.iloc[i, 0]
    value_2 = df_names.iloc[i, 1]
    df_names.iloc[i, -1] = matchscore(value_1, value_2)

# %%
df_names
# Out:
#                                 long_name               Player  ratio
# 0    Ahmed Eissa El Mohamady Abdel Fattah     Ahmed Elmohamady     58
# 1                            Ahmed Hegazy         Ahmed Hegazi     92
# 2        Ahmed Fathy Abdel Meneim Ibrahim          Ahmed Fathy     51
# 3     Mohamed Abdul Shafy Sayed Abouezeid  Mohamed Abdel-Shafy     63
# 4                Saad Ali Saadeldin Samir           Saad Samir     59
# ..                                    ...                  ...    ...
# 223                       Łukasz Piszczek      Łukasz Piszczek    100
# 224                           Saliou Ciss          Saliou Ciss    100
# 225                     Kalidou Koulibaly    Kalidou Koulibaly    100
# 226                        Lamine Gassama       Lamine Gassama    100
# 227                          Moussa Wagué         Moussa Wagué    100
#
# [228 rows x 3 columns]

# %%
df_names.to_excel("set.xlsx")

# %%
df_tgt
# Out:
#         Team Group  Squad Number Position               Player Date Of Birth  \
# 0      Egypt     A             3       DF     Ahmed Elmohamady    1987-09-09
# 1      Egypt     A             6       DF         Ahmed Hegazi    1991-01-25
# 2      Egypt     A             7       DF          Ahmed Fathy    1984-11-10
# 3      Egypt     A            13       DF  Mohamed Abdel-Shafy    1985-07-01
# 4      Egypt     A            20       DF           Saad Samir    1989-04-01
# ..       ...   ...           ...      ...                  ...           ...
# 223   Poland     H            20       DF      Łukasz Piszczek    1985-06-03
# 224  Senegal     H             2       DF          Saliou Ciss    1989-06-15
# 225  Senegal     H             3       DF    Kalidou Koulibaly    1991-06-20
# 226  Senegal     H            21       DF       Lamine Gassama    1989-10-20
# 227  Senegal     H            22       DF         Moussa Wagué    1998-10-04
#
#      Age  Caps  Goals                  Club  ...   lwb   ldm   cdm   rdm  \
# 0     30    77      2           Aston Villa  ...  72+0  70+1  70+1  70+1
# 1     27    44      1  West Bromwich Albion  ...  58+1  65+1  65+1  65+1
# 2     33   125      3               Al Ahly  ...  67+0  66+1  66+1  66+1
# 3     32    50      1              Al-Fateh  ...  70+1  67+1  67+1  67+1
# 4     29    11      0               Al Ahly  ...  65+1  64+1  64+1  64+1
# ..   ...   ...    ...                   ...  ...   ...   ...   ...   ...
# 223   33    61      3     Borussia Dortmund  ...  81+2  79+2  79+2  79+2
# 224   28    18      0          Valenciennes  ...  68+1  66+1  66+1  66+1
# 225   26    24      0                Napoli  ...  70+1  73+1  73+1  73+1
# 226   28    35      0            Alanyaspor  ...  67+1  66+1  66+1  66+1
# 227   19     9      0                 Eupen  ...  62+1  55+1  55+1  55+1
#
#       rwb    lb   lcb    cb   rcb    rb
# 0    72+0  71+1  68+1  68+1  68+1  71+1
# 1    58+1  61+1  72+1  72+1  72+1  61+1
# 2    67+0  66+1  64+1  64+1  64+1  66+1
# 3    70+1  70+1  68+1  68+1  68+1  70+1
# 4    65+1  68+1  69+1  69+1  69+1  68+1
# ..    ...   ...   ...   ...   ...   ...
# 223  81+2  81+2  80+2  80+2  80+2  81+2
# 224  68+1  68+1  68+1  68+1  68+1  68+1
# 225  70+1  74+1  83+1  83+1  83+1  74+1
# 226  67+1  67+1  66+1  66+1  66+1  67+1
# 227  62+1  63+1  59+1  59+1  59+1  63+1
#
# [228 rows x 117 columns]

# %% [markdown]
# ## Creating dataframe for analysis

# %%
results = pd.read_csv("Results.csv")

# %%
results.head(2)
# Out:
#    Country  Score
# 0  Uruguay      3
# 1   Russia      3

# %%
df_physical = df_tgt[['Team', 'Player', 'height_cm', 'weight_kg']]

# %%
df_physical.head(2)
# Out:
#     Team            Player  height_cm  weight_kg
# 0  Egypt  Ahmed Elmohamady        182         78
# 1  Egypt      Ahmed Hegazi        195         83

# %%
df_physical =  pd.merge(df_physical, results, left_on = 'Team', right_on = 'Country')

# %%
df_physical
# Out:
#         Team               Player  height_cm  weight_kg  Country  Score
# 0      Egypt     Ahmed Elmohamady        182         78    Egypt      1
# 1      Egypt         Ahmed Hegazi        195         83    Egypt      1
# 2      Egypt          Ahmed Fathy        175         72    Egypt      1
# 3      Egypt  Mohamed Abdel-Shafy        170         71    Egypt      1
# 4      Egypt           Saad Samir        185         76    Egypt      1
# ..       ...                  ...        ...        ...      ...    ...
# 223   Poland      Łukasz Piszczek        184         79   Poland      1
# 224  Senegal          Saliou Ciss        175         70  Senegal      1
# 225  Senegal    Kalidou Koulibaly        195         89  Senegal      1
# 226  Senegal       Lamine Gassama        181         74  Senegal      1
# 227  Senegal         Moussa Wagué        171         60  Senegal      1
#
# [228 rows x 6 columns]

# %%
df_physical.groupby("Team").mean().groupby("Score").mean()
# Out:
#         height_cm  weight_kg
# Score
# 1.0    182.937302  77.257778
# 2.0    182.323958  76.811806
# 3.0    184.341270  78.468254
# 4.0    182.733333  75.600000
# 5.0    188.428571  86.285714
# 6.0    186.833333  81.166667
# 7.0    183.636364  77.272727

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
web = f'https://en.wikipedia.org/wiki/National_team_appearances_in_the_FIFA_World_Cup'
response = requests.get(web)
content = response.text
soup = BeautifulSoup(content, 'lxml')
table = soup.find('table')

# %%
df=pd.DataFrame(pd.read_html(str(table))[0])

# %%
df
# Out:
#                       Team  Appearances  Record streak  Active streak  Debut  \
# 0                   Brazil           22             22             22   1930
# 1                  Germany           20             18             18   1934
# 2                Argentina           18             13             13   1930
# 3                    Italy           18             14              0   1934
# 4                   Mexico           17              8              8   1930
# ..                     ...          ...            ...            ...    ...
# 74                Slovakia            1              1              0   2010
# 75  Bosnia and Herzegovina            1              1              0   2014
# 76                 Iceland            1              1              0   2018
# 77                  Panama            1              1              0   2018
# 78                   Qatar            1              1              0   2022
#
#     Most recent                   Best result (* = hosts)
# 0          2022  Champions (1958, 1962, 1970, 1994, 2002)
# 1          2022       Champions (1954, 1974*, 1990, 2014)
# 2          2022                   Champions (1978*, 1986)
# 3          2014       Champions (1934*, 1938, 1982, 2006)
# 4          2022              Quarterfinals (1970*, 1986*)
# ..          ...                                       ...
# 74         2010                        Round of 16 (2010)
# 75         2014                               Group Stage
# 76         2018                               Group Stage
# 77         2018                               Group Stage
# 78         2022                                       TBD
#
# [79 rows x 7 columns]

# %% [markdown]
# # Q1

# %%
import worldcup
import pandas as pd

# %%
spain = worldcup.squad("Spain", 2006)

# %%
spain_df = pd.DataFrame(spain)

# %%
spain_df
# Out:
#     player_id  position_id  number  captain  injured  minutes  appearences  \
# 0      187215            1    23.0        0    False    540.0          6.0
# 1      185530            2    18.0        0    False    282.0          4.0
# 2        1330            2     2.0        0    False    267.0          3.0
# 3      186910            3    16.0        0    False    241.0          3.0
# 4      185571            3     8.0        1     True    258.0          5.0
# 5      186025            4    22.0        0    False    339.0          6.0
# 6      186968            3    19.0        0    False    194.0          5.0
# 7      129660            4     7.0        0    False    321.0          5.0
# 8       31647            2    20.0        0    False    270.0          3.0
# 9      380970            2     4.0        0    False    360.0          4.0
# 10   37459030            3     9.0        0    False    395.0          6.0
# ...

# %%
spain_df.columns
# Out:
# Index(['player_id', 'position_id', 'number', 'captain', 'injured', 'minutes',
#        'appearences', 'lineups', 'substitute_in', 'substitute_out',
#        'substitutes_on_bench', 'goals', 'owngoals', 'assists', 'saves',
#        'inside_box_saves', 'dispossesed', 'interceptions', 'yellowcards',
#        'yellowred', 'redcards', 'tackles', 'blocks', 'hit_post', 'cleansheets',
#        'rating', 'fouls', 'crosses', 'dribbles', 'duels', 'passes',
#        'penalties', 'shots'],
#       dtype='object')

# %%
spain_df[spain_df['number'] == 7]
# Out:
#    player_id  position_id  number  captain  injured  minutes  appearences  \
# 7     129660            4     7.0        0    False    321.0          5.0
#
#    lineups  substitute_in  substitute_out  ...  hit_post  cleansheets rating  \
# 7      4.0            1.0             3.0  ...       NaN          3.0   7.12
#
#                            fouls                         crosses  \
# 7  {'committed': 2, 'drawn': 12}  {'total': 6, 'accurate': None}
#
#                                             dribbles  \
# 7  {'attempts': 5, 'success': 4, 'dribbled_past':...
#
#                       duels                                          passes  \
# 7  {'total': 34, 'won': 21}  {'total': 99, 'accuracy': 84, 'key_passes': 4}
#
#                                            penalties  \
# 7  {'won': None, 'scores': None, 'missed': None, ...
#
#                                                shots
# 7  {'shots_total': 8, 'shots_on_target': 4, 'shot...
#
# [1 rows x 33 columns]

# %%
worldcup.player(129660)
# Out:
# [{'player_id': 129660,
#   'team_id': 7980,
#   'country_id': 32,
#   'position_id': 4,
#   'common_name': 'Á. Morata Martín',
#   'display_name': 'Morata',
#   'fullname': 'Álvaro Borja Morata Martín',
#   'firstname': 'Álvaro Borja',
#   'lastname': 'Morata Martín',
#   'nationality': 'Spain',
#   'birthdate': '23/10/1992',
#   'birthcountry': 'Spain',
#   'birthplace': 'Madrid',
#   'height': '189 cm',
#   'weight': '85 kg',
#   'image_path': 'https://cdn.sportmonks.com/images/soccer/players/28/129660.png'}]

# %% [markdown]
# # Q2

# %%
brazil = worldcup.squad("Brazil", 2014)
brazil_df = pd.DataFrame(brazil)

# %%
brazil_df.columns
# Out:
# Index(['player_id', 'position_id', 'number', 'captain', 'injured', 'minutes',
#        'appearences', 'lineups', 'substitute_in', 'substitute_out',
#        'substitutes_on_bench', 'goals', 'owngoals', 'assists', 'saves',
#        'inside_box_saves', 'dispossesed', 'interceptions', 'yellowcards',
#        'yellowred', 'redcards', 'tackles', 'blocks', 'hit_post', 'cleansheets',
#        'rating', 'fouls', 'crosses', 'dribbles', 'duels', 'passes',
#        'penalties', 'shots'],
#       dtype='object')

# %%
brazil_df.shape
# Out:
# (26, 33)

# %%
max = 0
for i in brazil_df["fouls"]:
    if i["committed"] is None:
        pass
    
    else:
        if i["committed"] > max["committed"]:
            max = i
            print(max)
print(max)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/guozixian/Downloads/WorldCupApi/main.ipynb Cell 13 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/guozixian/Downloads/WorldCupApi/main.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>     pass
#       <a href='vscode-notebook-cell:/Users/guozixian/Downloads/WorldCupApi/main.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> else:
# ----> <a href='vscode-notebook-cell:/Users/guozixian/Downloads/WorldCupApi/main.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a>     if i["committed"] > max["committed"]:
#       <a href='vscode-notebook-cell:/Users/guozixian/Downloads/WorldCupApi/main.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a>         max = i
#       <a href='vscode-notebook-cell:/Users/guozixian/Downloads/WorldCupApi/main.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a>         print(max)
#
# TypeError: 'int' object is not subscriptable

# %%
brazil_df
# Out:
#     player_id  position_id number  captain  injured  minutes  appearences  \
# 0       96208            2   None        1    False   1182.0         14.0
# 1      220052            3   None        0    False    963.0         14.0
# 2      159700            3   None        2    False    790.0          9.0
# 3      186320            4   None        0    False    900.0         10.0
# 4      460160            2   None        0    False    701.0          8.0
# 5      600687            4   None        0    False    406.0          7.0
# 6       95792            2   None        3    False    881.0         10.0
# 7       96099            3   None        0    False    533.0          9.0
# 8      129820            1   None        0    False    720.0          8.0
# 9      205411            3   None        0    False    594.0          8.0
# 10     130177            2   None        0    False    207.0          5.0
# 11     459145            3   None        0    False    165.0          5.0
# ...

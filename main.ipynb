# %% [markdown]
# # Question 1

# %% [markdown]
# **Prompt**
#
# *“Defenders often need to be physically strong in order to compete and progress in the world cup”. Investigate the validity of this claim using the world cup data provided.*

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import worldcup as wc

# %% [markdown]
# ## Data Collection

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
web = f'https://en.wikipedia.org/wiki/National_team_appearances_in_the_FIFA_World_Cup'
response = requests.get(web)
content = response.text
soup = BeautifulSoup(content, 'lxml')
table = soup.find('table')

# %%
df_teams = pd.DataFrame(pd.read_html(str(table))[0])
teams = df_teams[df_teams['Debut'] != 2022]['Team']

# %%
pd.DataFrame(wc.squad('Brazil', 2006))
# Out:
#     player_id  position_id number  captain  injured minutes appearences  \
# 0      129820            1   None        0    False    None        None
# 1       96208            2   None        0    False    None        None
# 2       95792            2   None        0    False    None        None
# 3      460160            2   None        0    False    None        None
# 4      130177            2   None        0    False    None        None
# 5      159700            3   None        0    False    None        None
# 6      459145            3   None        0    False    None        None
# 7      205411            3   None        0    False    None        None
# 8       96099            3   None        0    False    None        None
# 9      220052            3   None        0    False    None        None
# 10     186320            4   None        0    False    None        None
# 11     219633            4   None        0    False    None        None
# ...

# %%
years = [2006, 2010, 2014,2018]
teams = teams.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/guozixian/Development/WorldCupApi/main.ipynb Cell 9 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/guozixian/Development/WorldCupApi/main.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> years = [2006, 2010, 2014,2018]
# ----> <a href='vscode-notebook-cell:/Users/guozixian/Development/WorldCupApi/main.ipynb#X46sZmlsZQ%3D%3D?line=1'>2</a> teams = teams.tolist()
#       <a href='vscode-notebook-cell:/Users/guozixian/Development/WorldCupApi/main.ipynb#X46sZmlsZQ%3D%3D?line=2'>3</a> df = pd.DataFrame()
#
# AttributeError: 'list' object has no attribute 'tolist'

# %%
df = pd.DataFrame()

# %%
for year in years:
    for team in teams:
        df = pd.concat([df, pd.DataFrame(wc.squad(team, year))])
        print(f"fetching {year} {team}")
# Out:
# fetching 2006 Brazil
# fetching 2006 Germany
# fetching 2006 Argentina
# fetching 2006 Italy
# fetching 2006 Mexico
# fetching 2006 Spain
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/guozixian/Development/WorldCupApi/main.ipynb Cell 11 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/guozixian/Development/WorldCupApi/main.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> for year in years:
#       <a href='vscode-notebook-cell:/Users/guozixian/Development/WorldCupApi/main.ipynb#X50sZmlsZQ%3D%3D?line=1'>2</a>     for team in teams:
# ----> <a href='vscode-notebook-cell:/Users/guozixian/Development/WorldCupApi/main.ipynb#X50sZmlsZQ%3D%3D?line=2'>3</a>         df = pd.concat([df, pd.DataFrame(wc.squad(team, year))])
# ...
